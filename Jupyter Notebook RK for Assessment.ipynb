# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## **Ramkumaar Shanker**
# Business Advisor for start-ups as well as Analytics Program Manager

# %% [markdown]
# #### _I am interested in data science because it is both mathematical and statistical and helps in providing a better solution for business issues. It provides us an opportunity to predict outcomes based on various parameters_

# %% [markdown]
# ### In the subsequent section, the piece of code is expected to have 2 variables a and b both that have values. We have a thrid variable c which will have the sum of a & b. We will show the output of a & b in the subsequent piece of code

# %%
## This program is meant to capture the sum of 2 numbers and show the output
a = 5
b = 6
c = a + b
print(c)
# Out:
# 11

# %% [markdown]
# ## The below is an example for bullets, hyperlinks and numbered lists
# -  Bulleted Item
#     -  Sub-bulleted Item
#
# 1. Example 1
# 1. Example 2
#     1. Example 3
#
# --[IBM Cloud Link](https://cloud.ibm.com/)--
